# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('aps_failure_training_set.csv', skiprows=20)

# %%
test = pd.read_csv('aps_failure_test_set.csv', skiprows=20)

# %%
df.shape
# Out:
# (60000, 171)

# %%
test.shape
# Out:
# (16000, 171)

# %%
full_data = pd.concat([df, test])

# %%
full_data
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0       neg   76698     na  2130706438    280      0      0      0      0
# 1       neg   33058     na           0     na      0      0      0      0
# 2       neg   41040     na         228    100      0      0      0      0
# 3       neg      12      0          70     66      0     10      0      0
# 4       neg   60874     na        1368    458      0      0      0      0
# ...     ...     ...    ...         ...    ...    ...    ...    ...    ...
# 15995   neg   81852     na  2130706432    892      0      0      0      0
# 15996   neg      18      0          52     46      8     26      0      0
# 15997   neg   79636     na        1670   1518      0      0      0      0
# 15998   neg     110     na          36     32      0      0      0      0
# 15999   neg       8      0           6      4      2      2      0      0
#
#       ag_002  ...   ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008  \
# ...

# %%
full_data = full_data.replace('na', np.nan)

# %%
full_data['class'].replace('neg', 0, inplace=True)
full_data['class'].replace('pos', 1, inplace=True)

# %%
full_data.to_csv('full_data.csv', index=False)
